# %%
# PRACTICE TWO WEEK_1

#python program to print strings and type
str1 = 'Hi my name is Moses, I am a software engineer.'
str2 = 'Hi my name is Mahfuz, I am also a software engineer.'

#displaying string str1 and its type
print(str1)
print('Data Type for str1 is',type(str1))

#displaying string str2 and its type
print(str2)
print('Data Type for str2 is',type(str2))
# Out:
# Hi my name is Moses, I am a software engineer.
# Data Type for str1 is <class 'str'>
# Hi my name is Mahfuz, I am also a software engineer.
# Data Type for str2 is <class 'str'>
