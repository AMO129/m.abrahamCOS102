# %% [markdown]
# FLOWCHART
#
# ![Project_3.drawio.png](attachment:cea2c704-ef13-4da9-b898-4bc2fcd85358.png)

# %%
#Import necessary library
import pandas as pd

#Creating the table using list in list method

data = [
    ['Evelyn', 17, 5.5, 80, 'Female'],
    ['Chinedu', 19, 5.7, 74, 'Male'],
    ['Jessica', 16, 6.0, 85, 'Female'],
    ['Liam', 17, 5.4, 87, 'Male'],
    ['Somto', 17, 5.4, 70, 'Female'],
    ['Wale', 18, 5.8, 75, 'Male'],
    ['Edith', 18, 5.9, 60, 'Female'],
    ['Gbenga', 17, 6.1, 68, 'Male'],
    ['Liza', 16, 5.6, 76, 'Female'],
    ['Abiola', 20, 5.9, 68, 'Male'],
    ['Madonna', 18, 5.5, 66, 'Female'],
    ['Kola', 19, 5.5, 78, 'Male'],
    ['Waje', 17, 6.1, 87, 'Female'],
    ['Kunle', 16, 6.1, 87, 'Male'],
    ['Tola', 20, 6.0, 95, 'Female'],
    ['George', 18, 5.4, 98, 'Male'],
    ['Aisha', 19, 5.7, 50, 'Female'],
    ['Thomas', 17, 5.8, 54, 'Male'],
    ['Latifa', 17, 5.5, 49, 'Female'],
    ['Wesley',19, 5.7, 60, 'Male']
]

#Headers for table
headers = ['Name', 'Age', 'Height', 'Score', 'Gender']

#Creating the data frame
df = pd.DataFrame(data, columns=headers)

#Display table
print(df)
# Out:
#        Name  Age  Height  Score  Gender
# 0    Evelyn   17     5.5     80  Female
# 1   Chinedu   19     5.7     74    Male
# 2   Jessica   16     6.0     85  Female
# 3      Liam   17     5.4     87    Male
# 4     Somto   17     5.4     70  Female
# 5      Wale   18     5.8     75    Male
# 6     Edith   18     5.9     60  Female
# 7    Gbenga   17     6.1     68    Male
# 8      Liza   16     5.6     76  Female
# 9    Abiola   20     5.9     68    Male
# 10  Madonna   18     5.5     66  Female
# 11     Kola   19     5.5     78    Male
# 12     Waje   17     6.1     87  Female
# 13    Kunle   16     6.1     87    Male
# 14     Tola   20     6.0     95  Female
# 15   George   18     5.4     98    Male
# 16    Aisha   19     5.7     50  Female
# 17   Thomas   17     5.8     54    Male
# 18   Latifa   17     5.5     49  Female
# 19   Wesley   19     5.7     60    Male
