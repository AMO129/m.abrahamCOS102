# %%
str = input("Enter your state of origin:")  

print ("Your state of origin is: ", str) 
print ("The first character is: ", str[0]) 
print ("The characters starting from 3rd to 5th are: ", str[2:5]) 
print ("The string starting from 3rd character is: ", str[2:]) 
print ("State of origin two times", str * 2)
# Out:
# Enter your state of origin: Nasarawa
# Your state of origin is:  Nasarawa
# The first character is:  N
# The characters starting from 3rd to 5th are:  sar
# The string starting from 3rd character is:  sarawa
# State of origin two times NasarawaNasarawa

# %%
# Input from user 
m = float(input("Enter mass in kilograms: "))  

# Constant value for the speed of light in m/s 
c = 299792458  

# Calculating energy using Einstein's equation 
energy = m * c ** 2  

# Displaying the result 
print(f"The energy equivalent to {m} kg of mass is {energy} joules.")
# Out:
# Enter mass in kilograms:  25
# The energy equivalent to 25.0 kg of mass is 2.246887946842044e+18 joules.

# %%
list = [ 'Anaconda', 786 , 2.23, 'Jupyter', 70.2 ] 
shortlist = [321, 'Python' ]  

print(list)  #Prints complete list
print(list[0])    # Prints first element of the list 
print(list[1:3])  # Prints elements starting from 2nd till 3rd 
print(list[2:])   #Prints elements starting from 3rd element 
print(shortlist * 2)     # Prints list two times 
print(list + shortlist)  # Prints concatenated lists
# Out:
# ['Anaconda', 786, 2.23, 'Jupyter', 70.2]
# Anaconda
# [786, 2.23]
# [2.23, 'Jupyter', 70.2]
# [321, 'Python', 321, 'Python']
# ['Anaconda', 786, 2.23, 'Jupyter', 70.2, 321, 'Python']

# %%
tuple = ('Sokoto', 752, 'Oshogbo', 250, 'Akure', 500)
s_tuple = ('Abeokuta', 300, 'Ogbomoso')

#prints the complete tuple
print(tuple)

#prints last element of the tuple
print(tuple[-1])

#prints elements of the tuple starting from 2nd index till 3rd index
print(tuple[2:4])

#prints eements of the tuple starting from the 3rd index
print(tuple[3:])

#prints the contents of the tuple twice
print(s_tuple * 2)

#prints concatenated tuple
print(tuple + s_tuple)
# Out:
# ('Sokoto', 752, 'Oshogbo', 250, 'Akure', 500)
# 500
# ('Oshogbo', 250)
# (250, 'Akure', 500)
# ('Abeokuta', 300, 'Ogbomoso', 'Abeokuta', 300, 'Ogbomoso')
# ('Sokoto', 752, 'Oshogbo', 250, 'Akure', 500, 'Abeokuta', 300, 'Ogbomoso')

# %%
# Returns false as game_1 is not equal to game_2
game_1 = 2
game_2 = 4
print(bool(game_1 == game_2))

#or
print(game_1 == game_2)

#Returns false as val is None
val = None
print(bool(val))

#Returns false as num is an empty sequence
num = ()
print(bool(num))

#Return true as age is boolean
age = True
print(bool(age))
# Out:
# False
# False
# False
# False
# True

# %%
#convert to int
grade = int(70)   #grade will be 70
gpa = int(4.9)    #gpa will be 4
cgpa = int("4")   #cgpa will be 4

print(f"Grade = {grade}")
print(f"GPA = {gpa}")
print(f"CGPA = {cgpa}")
# Out:
# Grade = 70
# GPA = 4
# CGPA = 4

# %%
#convert to float

grade = float(97)
gpa = float(5)
cgpa = float("4.7")

print(f'Grade = {grade}')
print(f'GPA = {gpa}')
print(f'CGPA = {cgpa}')
# Out:
# Grade = 97.0
# GPA = 5.0
# CGPA = 4.7
