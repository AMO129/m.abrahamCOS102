# %% [markdown]
# A) PSEUDOCODE FOR STORE CHECKOUT
#
# BEGIN
#
# INPUT scan barcode_data
#
# INPUT item(s) weight
#
# READ item(s) FROM store's database
#
# DISPLAY item(s)
#
# IF item(s) is in store's database THEN
#
# COMPUTE item price = weight*price_rate
#
# IF discount IS true THEN
#
# COMPUTE total_amount = price - discount
#
# ELSE total_amount = price
#
# THEN make payment
#
# IF payment IS successful
#
# COMPUTE generate payment receipt
#
# PRINT receipt
#
# OUTPUT show receipt to security guard when prompted THEN exit store
#
# ELSE just exit store
#
# END
#
#
#
#
#
#
#
#
#
#
#
# FLOWCHART
#
# ![STORE CHECKOUT.drawio.png](attachment:0b7fefeb-9b8d-4fe3-8d49-3c692ebd3584.png)
#
#
#
#
#
#
#
#
#
# B) FLOWCHART
#
# ![MORNING ROUTINE.drawio.png](attachment:8e5139f9-39de-46f5-ac6d-06169cbae433.png)
#
#
#
#
#
# C)
#
# ![AGE AND NAMES MAPPING.drawio.png](attachment:fc2bf279-50eb-40ed-a492-20f2723bd669.png)
